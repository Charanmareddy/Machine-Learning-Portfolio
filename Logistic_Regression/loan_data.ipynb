# %%
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder,RobustScaler
from sklearn.metrics import confusion_matrix,classification_report

# %%
df = pd.read_csv('loan_data.csv')

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
x = df.drop(columns='loan_status')
y = df['loan_status']

# %%
x
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
x.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file'],
#       dtype='object')

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 44995    1
# 44996    1
# 44997    1
# 44998    1
# 44999    1
# Name: loan_status, Length: 45000, dtype: int64

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
df.corr(numeric_only=True)
# Out:
#                             person_age  person_income  person_emp_exp  \
# person_age                    1.000000       0.193698        0.954412
# person_income                 0.193698       1.000000        0.185987
# person_emp_exp                0.954412       0.185987        1.000000
# loan_amnt                     0.050750       0.242290        0.044589
# loan_int_rate                 0.013402       0.001510        0.016631
# loan_percent_income          -0.043299      -0.234177       -0.039862
# cb_person_cred_hist_length    0.861985       0.124316        0.824272
# credit_score                  0.178432       0.035919        0.186196
# loan_status                  -0.021476      -0.135808       -0.020481
#
#                             loan_amnt  loan_int_rate  loan_percent_income  \
# person_age                   0.050750       0.013402            -0.043299
# person_income                0.242290       0.001510            -0.234177
# ...

# %%
num_cols = x.select_dtypes(include='number').columns
obj_cols = x.select_dtypes(include='object').columns

# %%
num_cols
# Out:
# Index(['person_age', 'person_income', 'person_emp_exp', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score'],
#       dtype='object')

# %%
sns.boxplot(x[num_cols])
# Out:
# <Axes: >

# %%
num_cols = x.select_dtypes(include='number').columns

cols = 3
rows = math.ceil(len(num_cols) / cols)

fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    axes[i].boxplot(df[col])
    axes[i].set_title(col)

# Remove unused axes if any
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
x[obj_cols].nunique()
# Out:
# person_gender                     2
# person_education                  5
# person_home_ownership             4
# loan_intent                       6
# previous_loan_defaults_on_file    2
# dtype: int64

# %%
encoder =  OneHotEncoder(sparse_output=False,handle_unknown='ignore')

scaling  =  RobustScaler()
model = LogisticRegression()

# %%
xtrain[num_cols] = scaling.fit_transform(xtrain[num_cols])

encoded_values =  encoder.fit_transform(xtrain[obj_cols])
encoded_xtrain_columns = encoder.get_feature_names_out()
encoded_xtrain_columns
# Out:
# array(['person_gender_female', 'person_gender_male',
#        'person_education_Associate', 'person_education_Bachelor',
#        'person_education_Doctorate', 'person_education_High School',
#        'person_education_Master', 'person_home_ownership_MORTGAGE',
#        'person_home_ownership_OTHER', 'person_home_ownership_OWN',
#        'person_home_ownership_RENT', 'loan_intent_DEBTCONSOLIDATION',
#        'loan_intent_EDUCATION', 'loan_intent_HOMEIMPROVEMENT',
#        'loan_intent_MEDICAL', 'loan_intent_PERSONAL',
#        'loan_intent_VENTURE', 'previous_loan_defaults_on_file_No',
#        'previous_loan_defaults_on_file_Yes'], dtype=object)

# %%
xtrain[encoded_xtrain_columns] = encoded_values
xtrain.drop(columns=obj_cols,inplace=True)

# %%
xtrain
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 25180    1.333333       0.621771        1.000000   0.965517       0.386517
# 12555   -0.166667       0.120777       -0.142857   0.551724       0.191011
# 29153    2.500000       5.265159        2.000000   2.206897      -0.143820
# 23838    0.166667       0.559271        0.000000   0.220690       1.377528
# 35686    0.166667       0.366411        0.428571  -0.129793       0.440449
# ...           ...            ...             ...        ...            ...
# 11284    0.000000       0.440142        0.285714   0.362069      -1.119101
# 44732   -0.166667      -0.666014       -0.142857  -0.292966       0.152809
# 38158    1.166667      -0.180825        0.714286   0.373379      -0.060674
# 860      0.000000       2.297872        0.285714   1.655172       1.568539
# 15795    0.000000       2.963309        0.000000   0.965517       0.000000
#
# ...

# %%
xtest[num_cols] =  scaling.transform(xtest[num_cols])

encoded_xtest_values = encoder.transform(xtest[obj_cols])
encoded_xtest_columns =  encoder.get_feature_names_out()
encoded_xtest_columns
# Out:
# array(['person_gender_female', 'person_gender_male',
#        'person_education_Associate', 'person_education_Bachelor',
#        'person_education_Doctorate', 'person_education_High School',
#        'person_education_Master', 'person_home_ownership_MORTGAGE',
#        'person_home_ownership_OTHER', 'person_home_ownership_OWN',
#        'person_home_ownership_RENT', 'loan_intent_DEBTCONSOLIDATION',
#        'loan_intent_EDUCATION', 'loan_intent_HOMEIMPROVEMENT',
#        'loan_intent_MEDICAL', 'loan_intent_PERSONAL',
#        'loan_intent_VENTURE', 'previous_loan_defaults_on_file_No',
#        'previous_loan_defaults_on_file_Yes'], dtype=object)

# %%
xtest[encoded_xtest_columns] = encoded_xtest_values
xtest.drop(columns= obj_cols,inplace=True)

# %%
xtest
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 37979    1.000000       0.613528        0.857143  -0.068966      -1.116854
# 9911    -0.333333      -0.211303        0.285714   0.137931       0.107865
# 43386   -0.666667      -0.613961       -0.571429  -0.413793       0.869663
# 13822   -0.500000      -0.559435       -0.428571  -0.413793       0.669663
# 44810    2.666667       0.018175        2.285714   0.275862       0.988764
# ...           ...            ...             ...        ...            ...
# 14572   -0.833333       1.362382       -0.571429   0.827586      -0.229213
# 30384    2.166667      -0.107218        1.857143  -0.175862       1.222472
# 36665   -0.333333       0.244356       -0.428571   0.827586       0.143820
# 30569    2.000000      -0.617176        1.714286   0.000000       0.000000
# 5321    -0.166667      -0.656865       -0.571429   0.068966       0.029213
#
# ...

# %%
# Training the model

model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Model Evaluation on train data

# %%
y_pred_train = model.predict(xtrain)

# %%
confusion_matrix(ytrain,y_pred_train)
# Out:
# array([[26314,  1696],
#        [ 2004,  5986]])

# %%
print(classification_report(ytrain,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93     28010
#            1       0.78      0.75      0.76      7990
#
#     accuracy                           0.90     36000
#    macro avg       0.85      0.84      0.85     36000
# weighted avg       0.90      0.90      0.90     36000

# %%
y.value_counts()
# Out:
# loan_status
# 0    35000
# 1    10000
# Name: count, dtype: int64

# %% [markdown]
# #### EValuation of Test Data

# %%
y_pred_test = model.predict(xtest)

# %%
print(classification_report(ytest,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      6990
#            1       0.77      0.74      0.76      2010
#
#     accuracy                           0.89      9000
#    macro avg       0.85      0.84      0.85      9000
# weighted avg       0.89      0.89      0.89      9000
